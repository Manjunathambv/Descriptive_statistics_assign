# %% [markdown]
# ## Case study 1

# %% [markdown]
# ### About the Data set (Wine Quality.csv)
# Attribute Information:
#
# The dataset are related to red and white variants of the "Vinho Verde" wine. Vinho verde is a unique product from the Minho (northwest) region of Portugal. Medium in alcohol, is it particularly appreciated due to its freshness (specially in the summer).
#
#     1 - fixed acidity
#     2 - volatile acidity
#     3 - citric acid
#     4 - residual sugar
#     5 - chlorides
#     6 - free sulfur dioxide
#     7 - total sulfur dioxide
#     8 - density
#     9 - pH
#     10 - sulphates
#     11 - alcohol Output variable (based on sensory data):
#     12 - quality (score between 0 and 10)
#
# ### Marks distribution
# 1. EDA Descriptive Statistics (10 marks)
# 2. Measures of Dispersion (5 marks)
# 3. Covariance and Correlation (5 marks)

# %% [markdown]
# ## 1. Load the libraries:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 2. Importing the dataset:

# %%
data = pd.read_csv("wine_data.csv")
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
data.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
data.get_dtype_counts()
# Out:
# float64    11
# int64       1
# dtype: int64

# %%
print(data.nunique())
print("\n")
print("shape of the data is ", data.shape)
# Out:
# fixed acidity            68
# volatile acidity        125
# citric acid              87
# residual sugar          310
# chlorides               160
# free sulfur dioxide     132
# total sulfur dioxide    251
# density                 890
# pH                      103
# sulphates                79
# alcohol                 103
# quality                   7
# dtype: int64
#
#
# shape of the data is  (4898, 12)

# %%
alcohol = data.alcohol
inputVariable = data.drop('alcohol', axis=1)
inputVariable.head()
alcohol.head()
# Out:
# 0     8.8
# 1     9.5
# 2    10.1
# 3     9.9
# 4     9.9
# Name: alcohol, dtype: float64

# %%
for variable in inputVariable:
    plt.hist(inputVariable[variable], bins=5,edgecolor = "black",color="magenta")
    plt.ylabel("Frquency")
    plt.xlabel(variable)
    plt.title("Frequency plots of " + variable)
    plt.show()
    
# for variable in inputVariable:
# #     plt.hist(inputVariable[variable], bins=5,edgecolor = "black",color="magenta")
#     sns.countplot(inputVariable[variable])
#     plt.ylabel("Frquency")
#     plt.xlabel(variable)
#     plt.title("Frequency plots of " + variable)
#     ax = plt.gca()
#     plt.show()

# %%
alcohol.min()
# Out:
# 8.0

# %%
alcohol.max()
# Out:
# 14.2

# %%
for variable in data:
    sns.barplot(x=np.round(data['alcohol']), y = data[variable])
    plt.xlabel('alcohol')
    plt.ylabel(variable)
    plt.title("barplot of alcohol vs "+variable)
    plt.show()

# %%
# A higher quality is usually associated with low volatile acidity levels
for variable in data:
    sns.barplot(x=data['quality'], y = variable, data=data)
    plt.show()

# %%
for variable in data:
    sns.barplot(x=np.round(data['alcohol']), y = data[variable], hue=data['quality'])
    plt.show()

# %%
for variable in data:
    sns.swarmplot(x=np.round(data['alcohol']), y = data[variable], hue=data['quality'])
    plt.xlabel('alcohol')
    plt.ylabel(variable)
    plt.title("barplot of alcohol vs "+variable)
    plt.show()

# %%
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %% [markdown]
# ## 3.EDA Descriptive Statistics:

# %% [markdown]
# ### 3.1.  Measures of Central Tendency
#
# Measures of Central Tendency define significant, representative and adequate values for a set of data, depending on what you want to analyze. They are the
#
# 1. mean
# 2. median
# 3. quantiles and mode.

# %% [markdown]
# ### 3.2 Check the  mean ,Mode, Median and Quantile for dataset?

# %% [markdown]
# #### Mean

# %% [markdown]
# # def basicStatistics(x):
#     x = pd.Series(x)
#     countValue = x.count()
#     missingValue = len(x)-count
#     meanValue = x.mean()
#     sumValue = x.sum()
#     std = x.std()
#     var = x.var()
#     Min = x.min()
#     p5 = x.quantile([0.05]).iloc[0]
#     p10 = x.quantile([0.1]).iloc[0]
#     p25 = x.quantile([0.25]).iloc[0]
#     p50 = x.quantile([0.5]).iloc[0]
#     p75 = x.quantile([0.75]).iloc[0]
#     p90 = x.quantile([0.9]).iloc[0]
#     p95 = x.quantile([0.95]).iloc[0]
#     p99 = x.quantile([0.99]).iloc[0]
#     Max = x.max()
#     IQR = p75 - p25
#
#     res = [countValue,missingValue,sumValue,meanValue,std,var,Min,p5,p10,p25,p50,p75,p90,p95,p99,Max,IQR]
#     ix = ["count","nmiss","Sum","mean","std","var","Min","p5","p10","p25","p50","p75","p90","p95","p99","Max","IQR"]
#     res = pd.Series(res, index=ix)
#     return res

# %%
def satMean(x):
    x = pd.Series(x)
    meanValue = x.mean()
    res = pd.Series(meanValue, index=["mean"])
    return res

# %%
data.apply(satMean)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# mean       6.854788          0.278241     0.334192        6.391415   0.045772
#
#       free sulfur dioxide  total sulfur dioxide   density        pH  \
# mean            35.308085            138.360657  0.994027  3.188267
#
#       sulphates    alcohol   quality
# mean   0.489847  10.514267  5.877909

# %% [markdown]
# #### Mode

# %%
def satMode(x):
    x = pd.Series(x)
    modeValue = x.mode().iloc[0]
    res = pd.Series(modeValue, index=["mode"])
    return res

# %%
data.apply(satMode)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# mode            6.8              0.28          0.3             1.2      0.044
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# mode                 29.0                 111.0    0.992  3.14        0.5
#
#       alcohol  quality
# mode      9.4        6

# %% [markdown]
# #### Median and Quantile

# %% [markdown]
# ### 3.4 check (Quantile 25%,50%,75%) for dataset

# %% [markdown]
# #### Quantile 25%

# %%
def sat25Qualtile(x):
    x = pd.Series(x)
    p25 = x.quantile([0.25]).iloc[0]
    res = pd.Series(p25, index=["25%_Quantile"])
    return res

# %%
data.apply(sat25Qualtile)
# Out:
#               fixed acidity  volatile acidity  citric acid  residual sugar  \
# 25%_Quantile            6.3              0.21         0.27             1.7
#
#               chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# 25%_Quantile      0.036                 23.0                 108.0  0.991723
#
#                 pH  sulphates  alcohol  quality
# 25%_Quantile  3.09       0.41      9.5      5.0

# %% [markdown]
# #### Quantile 50% OR MEDIAN

# %%
def sat50Qualtile(x):
    x = pd.Series(x)
    p50 = x.quantile([0.5]).iloc[0]
    res = pd.Series(p50, index=["50%_Quantile"])
    return res

# %%
data.apply(sat50Qualtile)
# Out:
#               fixed acidity  volatile acidity  citric acid  residual sugar  \
# 50%_Quantile            6.8              0.26         0.32             5.2
#
#               chlorides  free sulfur dioxide  total sulfur dioxide  density  \
# 50%_Quantile      0.043                 34.0                 134.0  0.99374
#
#                 pH  sulphates  alcohol  quality
# 50%_Quantile  3.18       0.47     10.4      6.0

# %% [markdown]
# #### Quantile 75%

# %%
def sat75Qualtile(x):
    x = pd.Series(x)
    p75 = x.quantile([0.75]).iloc[0]
    res = pd.Series(p75, index=["75%_Quantile"])
    return res

# %%
data.apply(sat75Qualtile)
# Out:
#               fixed acidity  volatile acidity  citric acid  residual sugar  \
# 75%_Quantile            7.3              0.32         0.39             9.9
#
#               chlorides  free sulfur dioxide  total sulfur dioxide  density  \
# 75%_Quantile       0.05                 46.0                 167.0   0.9961
#
#                 pH  sulphates  alcohol  quality
# 75%_Quantile  3.28       0.55     11.4      6.0

# %% [markdown]
# ## 4. Measures of Dispersion

# %% [markdown]
# Measures of Dispersion are measures that indicate how spread the data is, or how they vary. The measures of dispersion are range, variance, standard deviation and the absolute deviation, or mean absolute deviation.

# %% [markdown]
# ### 4.1 check the Range,Variance,Standard Deviation,Absolute Deviation or Mean Absolute Deviation?

# %% [markdown]
# #### Range

# %%
def iqrRange(x):
    x = pd.Series(x)
    p25 = x.quantile([0.25]).iloc[0]
    p75 = x.quantile([0.75]).iloc[0]
    IQR_value = p75 - p25
    res = pd.Series(IQR_value, index=["IQR"])
    return res

# %%
data.apply(iqrRange)
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# IQR            1.0              0.11         0.12             8.2      0.014
#
#      free sulfur dioxide  total sulfur dioxide   density    pH  sulphates  \
# IQR                 23.0                  59.0  0.004377  0.19       0.14
#
#      alcohol  quality
# IQR      1.9      1.0

# %% [markdown]
# #### Variance

# %%
def varianceValue(x):
    x = pd.Series(x)
    varValue = x.var()
    res = pd.Series(varValue, index=["Variance"])
    return res

# %%
data.apply(varianceValue)
# Out:
#           fixed acidity  volatile acidity  citric acid  residual sugar  \
# Variance       0.712114           0.01016     0.014646        25.72577
#
#           chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# Variance   0.000477            289.24272           1806.085491  0.000009
#
#                 pH  sulphates   alcohol   quality
# Variance  0.022801   0.013025  1.514427  0.784356

# %% [markdown]
# #### Standard Deviation

# %%
def stdValue(x):
    x = pd.Series(x)
    stdValue = x.std()
    res = pd.Series(stdValue, index=["std_deviation"])
    return res

# %%
data.apply(stdValue)
# Out:
#                fixed acidity  volatile acidity  citric acid  residual sugar  \
# std_deviation       0.843868          0.100795      0.12102        5.072058
#
#                chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# std_deviation   0.021848            17.007137             42.498065  0.002991
#
#                      pH  sulphates   alcohol   quality
# std_deviation  0.151001   0.114126  1.230621  0.885639

# %% [markdown]
# #### Absolute Deviation or Mean Absolute Deviation

# %%
def madValue(x):
    x = pd.Series(x)
    madValue = x.mad()
    res = pd.Series(madValue, index=["Mean_absolute_deviation"])
    return res

# %%
data.apply(madValue)
# Out:
#                          fixed acidity  volatile acidity  citric acid  \
# Mean_absolute_deviation       0.644923          0.073803     0.086411
#
#                          residual sugar  chlorides  free sulfur dioxide  \
# Mean_absolute_deviation        4.227788   0.011462            13.149156
#
#                          total sulfur dioxide   density        pH  sulphates  \
# Mean_absolute_deviation             34.282442  0.002447  0.118204   0.087504
#
#                           alcohol   quality
# Mean_absolute_deviation  1.034213  0.670793

# %% [markdown]
# ## 5. Covariance and Correlation

# %% [markdown]
# 1. Covariance is a numerical measure that indicates the inter-dependency between two variables.
# 2. Covariance indicates how two variables behave together in relation to their averages.
# 3. A covariance of 0 indicates that the variables are totally independant, while a high and positive covariance value means that a variable is big when the other is big. Analogously, a negative covariance with a high absolute value means that one variable is big when the other is small.
# 4. Covariance can be calculated through the cov() function.

# %% [markdown]
# ### 5.1 Check the Covariance and Correlation scores . write your Observations?

# %% [markdown]
# #### Covariance

# %%
data.cov()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              0.712114         -0.001931     0.029533
# volatile acidity          -0.001931          0.010160    -0.001823
# citric acid                0.029533         -0.001823     0.014646
# residual sugar             0.381022          0.032865     0.057829
# chlorides                  0.000426          0.000155     0.000302
# free sulfur dioxide       -0.708919         -0.166300     0.193630
# total sulfur dioxide       3.266013          0.382354     0.622989
# density                    0.000670          0.000008     0.000054
# pH                        -0.054265         -0.000486    -0.002992
# sulphates                 -0.001651         -0.000411     0.000861
# alcohol                   -0.125533          0.008400    -0.011278
# quality                   -0.084947         -0.017382    -0.000987
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
plt.figure(figsize=(16,8))
sns.heatmap(data = data.cov(), annot=True)

plt.show()

# %% [markdown]
# #### Observation:

# %% [markdown]
# covariance just indiactes the relationship between the variable,
# however they are not compared with respect to each other beacuse of the unit difference
#
# However it indicates relationship between two variable
# 1)Total sulfur dioxide and sulfer oxide show a strong relationship
# 2) residual sugar and free sulfer aide show a strong relationship

# %% [markdown]
# #### Correlation

# %%
data.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.022697     0.289181
# volatile acidity          -0.022697          1.000000    -0.149472
# citric acid                0.289181         -0.149472     1.000000
# residual sugar             0.089021          0.064286     0.094212
# chlorides                  0.023086          0.070512     0.114364
# free sulfur dioxide       -0.049396         -0.097012     0.094077
# total sulfur dioxide       0.091070          0.089261     0.121131
# density                    0.265331          0.027114     0.149503
# pH                        -0.425858         -0.031915    -0.163748
# sulphates                 -0.017143         -0.035728     0.062331
# alcohol                   -0.120881          0.067718    -0.075729
# quality                   -0.113663         -0.194723    -0.009209
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
plt.figure(figsize=(12,8))
correlation = data.corr()
sns.heatmap(correlation, annot=True, cmap="coolwarm")
plt.show()

# %% [markdown]
# #### Observation:

# %% [markdown]
# 1) positive values show direct co-relationships between features.
# The higher the values, the stronger these relationships.
# That means, increase in one feature increases, the other, and vice-versa
#
# 2) The squares that have negative values show an inverse co-relationship.
#     ph is the power of hydrogen and acidity refers to fresh and sour tase
#     a) ph vs Fixed acidity increase in one decreases the other indicates acidity increases with decrease in ph
#     decrease in ph indicates wine becomes more and more towards the acidic state which is not good
#     b)density vs sugarLevel --> strong postive correlation indicates increase in the sugar increase the density

# %% [markdown]
# ### Example (Confidence Interval)

# %% [markdown]
# Hindustan Pencils Pvt. Ltd. is an Indian manufacturer of pencils, writing materials and other stationery items, established in 1958 in Mumbai. Nataraj brand of pencils manufactured by the company is expected to have a mean length of 172 mm and the standard deviation of the length is 0.02 mm.
#
# To ensure quality, a sample is selected at periodic intervals to determine whether the length is still 172 mm and other dimensions of the pencil meet the quality standards set by the company.
#
# You select a random sample of 100 pencils and the mean is 170 mm.
# Construct a 95% confidenct interval for the pencil length.

# %%
from scipy.stats import norm
import math

# %%
# @95% confidence interval
z = norm.ppf(0.95)
z
# Out:
# 1.6448536269514722

# %%
# population parameter giver
popMean = 172
popStdDev = 0.02

# sample observation given
n = 100
sampleMean = 170

'''
confidenceInterval = samplemean +or- margin error
margin error = z-score*population stand error
z-score = (xbar - mu)/(sigma/sqrt(n))
stad_error = sigma/sqrt(n)

obsevation from the problem statement

hypothesis testing saying that 
H0 : mu = 172
H1 : mu != 172
its a two tailed test
'''
std_error = popStdDev/(math.sqrt(n))
z_observed = (sampleMean - popMean)/std_error
margin_error = z_observed*std_error
lowerConfidenceInterval = sampleMean - z*std_error
upperConfidenceInterval = sampleMean + z*std_error 

z_critical = norm.ppf(0.025)


print("std error = ", std_error)
print("z_observed = ", z_observed)
print("marigin_error = ", margin_error)
print("LCI = ", lowerConfidenceInterval)
print("UCI = ", upperConfidenceInterval)
print("z_critical = ", z_critical)
# Out:
# std error =  0.002
# z_observed =  -1000.0
# marigin_error =  -2.0
# LCI =  169.9967102927461
# UCI =  170.0032897072539
# z_critical =  -1.9599639845400545

# %%
conclusion:
    
with respect to confidence intervale our population mean not fall in range LCI-UCI limit
and also with respect critical region and significance level of 5% z
# Out:
# z_critical =  -1.9599639845400545

# %% [markdown]
# # The End
